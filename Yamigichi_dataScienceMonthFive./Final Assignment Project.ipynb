# %%
import pandas as pan
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1010">Loading BokehJS ...</span>
#     </div>

# %%
def make_dashboard(x, gdp_change, unemployment, title, file_name):
    output_file(file_name)
    p = figure(title=title, x_axis_label='year', y_axis_label='%')
    p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend="% GDP change")
    p.line(x.squeeze(), unemployment.squeeze(), line_width=4, legend="% unemployed")
    show(p)

# %%
links={'GDP':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_gdp.csv',\
       'unemployment':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_unemployment.csv'}

# %% [markdown]
# *Create a dataframe that contains the GDP data and display the first five rows of the dataframe.*

# %%
import pandas as pan
csv_path= links['GDP']
df=pan.read_csv(csv_path)
df.head()
# Out:
#    date  level-current  level-chained  change-current  change-chained
# 0  1948          274.8         2020.0            -0.7            -0.6
# 1  1949          272.8         2008.9            10.0             8.7
# 2  1950          300.2         2184.0            15.7             8.0
# 3  1951          347.3         2360.0             5.9             4.1
# 4  1952          367.7         2456.1             6.0             4.7

# %% [markdown]
# *Create a dataframe that contains the unemployment data. Display the first five rows of the dataframe.*

# %%
import pandas as pan
csv_path=links['unemployment']
df=pan.read_csv(csv_path)
df.head()
# Out:
#    date  unemployment
# 0  1948      3.750000
# 1  1949      6.050000
# 2  1950      5.208333
# 3  1951      3.283333
# 4  1952      3.025000

# %% [markdown]
# *Display a dataframe where unemployment was greater than 8.5% . Take a screenshot*

# %%
import pandas as pan
csv_path=links['unemployment']
df=pan.read_csv(csv_path)
df1=df[df['unemployment']>8.5]
df1
# Out:
#     date  unemployment
# 34  1982      9.708333
# 35  1983      9.600000
# 61  2009      9.283333
# 62  2010      9.608333
# 63  2011      8.933333

# %%
import pandas as pan
links={'GDP':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_gdp.csv',\
       'unemployment':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_unemployment.csv'}
csv_path= links['GDP']
gdp_dataframe=pan.read_csv(csv_path)
x = pan.DataFrame(gdp_dataframe, columns=['date'])
x.head()
# Out:
#    date
# 0  1948
# 1  1949
# 2  1950
# 3  1951
# 4  1952

# %%
import pandas as pan
links={'GDP':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_gdp.csv',\
       'unemployment':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_unemployment.csv'}
csv_path= links['GDP']
gdp_dataframe=pan.read_csv(csv_path)
gdp_change=pan.DataFrame(gdp_dataframe, columns=['change-current'])
gdp_change.head()
# Out:
#    change-current
# 0            -0.7
# 1            10.0
# 2            15.7
# 3             5.9
# 4             6.0

# %%
import pandas as pan
links={'GDP':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_gdp.csv',\
       'unemployment':'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/clean_unemployment.csv'}
csv_path= links['unemployment']
unemploy_dataframe=pan.read_csv(csv_path)
unemployment=pan.DataFrame(unemploy_dataframe, columns=['unemployment'])
unemployment.head()
# Out:
#    unemployment
# 0      3.750000
# 1      6.050000
# 2      5.208333
# 3      3.283333
# 4      3.025000

# %% [markdown]
# *Create a title and file name*

# %%
# Give your dashboard a string title
title: 'Python For Data Science and Ai'

# %%
file_name = "first.html"

# %%
import pandas as pan
from bokeh.plotting import figure, output_file, show,output_notebook
output_notebook()

def make_dashboard(x = pan.DataFrame(gdp_dataframe, columns=['date']), gdp_change=pan.DataFrame(gdp_dataframe, columns=['change-current']), unemployment=pan.DataFrame(unemploy_dataframe, columns=['unemployment']), title='Python For Data Science and Ai', file_name="index.html"):
    output_file( "first.html")
    p = figure(title=title, x_axis_label='year', y_axis_label='%')
    p.line(x.squeeze(), gdp_change.squeeze(), color="firebrick", line_width=4, legend="% GDP change")
    p.line(x.squeeze(), unemployment.squeeze(), line_width=4, legend="% unemployed")
    show(p)
    m
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1258">Loading BokehJS ...</span>
#     </div>

# %%
make_dashboard()
# Out:
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead
#   <div class="bk-root" id="6ea6a706-1ce8-4438-8558-99dd28585a12" data-root-id="1013"></div>
